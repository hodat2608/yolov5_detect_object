# %%
path = r'C:\Users\AICCSX\Desktop\vu\combine\model\cam1\best1.pt'

# %%
import torch
model = torch.hub.load('./levu','custom', path= path, source='local',force_reload =False)

# %%
result = model('./img/image.jpg')

# %%
result.names
# Out:
# ['di_vat', 'bac_truc', 'tray_bac_truc', 'tray_day', 'nut']

# %%
table1 = result.pandas().xyxy[0]

# %%
table1
# Out:
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []

# %%
bytes([1000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0408dbd3500b> in <module>
# ----> 1 bytes([1000])
#
# ValueError: bytes must be in range(0, 256)

# %%
a = b'\x03\xE8'

# %%
int.from_bytes(a, 'big')
# Out:
# 1000

# %%
hex(1000)
# Out:
# '0x3e8'

# %%
def dectohex(number):
    hex = format(number, "03X")
    return hex.zfill(4)

# %%
register = dectohex(3000)

# %%
value_register = '\x{}\x00'.format('a')

# %%
value_register
# Out:
# '\x00\\b'

# %%
value_register = '\x00\{}'.format('b')

# %%
a = (1000).to_bytes(2, byteorder='big') + b'\x00'

# %%
a
# Out:
# b'\x03\xe8\x00'

# %%
def int_to_bytes(x: int) -> bytes:
    return x.to_bytes((x.bit_length() + 7) // 8, 'big')

# %%
int_to_bytes(1000)

# %%
import glob
if len(glob.glob(r'C:\Users\Administrator\Desktop\vu\Iot\excel\t\*')) == 4:
    for i in glob.glob(r'C:\Users\Administrator\Desktop\vu\Iot\excel\t\*'):
        if i %2 !=0:
# Out:
# C:\Users\Administrator\Desktop\vu\Iot\excel\t\1
# C:\Users\Administrator\Desktop\vu\Iot\excel\t\2
# C:\Users\Administrator\Desktop\vu\Iot\excel\t\3
# C:\Users\Administrator\Desktop\vu\Iot\excel\t\4

# %%
path = r'C:\Users\Administrator\Music\HINH_TRAIN_C1_17_07_2022 - Copy\*.txt'

# %%
di_vat
co_bac_truc
tray_bac_truc
day_vo_lon
dau_dinh_vi

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    for line in Lines:
        num = line.strip()[0]
        names.append(num)
    if '0' in names and '3' in names:
        print(names)
        with open(i,'w') as f:
            for line in Lines:
                if line.strip()[0] != "3":
                    f.write(line)
    #                 f.write('\n')

# %%
path = 'D:/DEN-CAM1/*.txt'

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    for line in Lines:
        w = line.strip().split(' ')[3]
        h = line.strip().split(' ')[4]
        if float(w)*416 > 3.1 and float(h)*416 > 3.1:
            names.append(line)
    with open(i,'w') as f:
        for name in names:
            f.write(name)

    #     names.append(num)
    # if '0' in names and '3' in names:
    #     print(names)
    #     with open(i,'w') as f:
    #         for line in Lines:
    #             if line.strip()[0] != "3":
    #                 f.write(line)
    # #                 f.write('\n')

# %%
path = 'C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy/*.txt'

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    files = []
    for line in Lines:
        num = line.strip()[0]
        names.append(num)
    if '0' in names and '4' in names:
        for line in Lines:      
            if line.strip()[0] == '4':
                x4 = float(line.strip().split(' ')[1])
                y4 = float(line.strip().split(' ')[2])
                w4 = float(line.strip().split(' ')[3])
                h4 = float(line.strip().split(' ')[4])
                xmin = x4 - w4/2
                xmax = x4 + w4/2
                ymin = y4 - h4/2
                ymax = y4 + h4/2
        for line in Lines:   
            if line.strip()[0] == '0':
                x0 = float(line.strip().split(' ')[1])
                y0 = float(line.strip().split(' ')[2])
                if xmin < x0 < xmax  and ymin < y0 < ymax:
                    for line in Lines:  
                        if line.strip()[0] == '4':
                            files.append(line)
        with open(i, 'w') as f:
            for line in Lines:
                if line not in files:
                    f.write(line)
# Out:
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\0.txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_07.txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (1).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (10).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (100).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (101).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (102).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (103).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (104).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (105).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (106).txt
# C:/Users/Administrator/Music/HINH_TRAIN_C1_17_07_2022 - Copy\02_070 (107).txt
# ...

# %%
# !wget --quiet https://raw.githubusercontent.com/tensorflow/models/master/official/nlp/bert/tokenization.py
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
path = r'C:\Users\Administrator\Music\cam1_image\*.txt'

# %%
import glob
for i in glob.glob(path):
    # path = i[:-4]
    # print(path)

    with open(i , 'a') as f:
        f.write('5 0.192500 0.556667 0.090000 0.096667')
        f.write('\n')
        f.write('5 0.808125 0.477083 0.087500 0.109167')

# %%
5 0.192500 0.556667 0.090000 0.096667
5 0.808125 0.477083 0.087500 0.109167

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    files = []
    xmaxlist = []
    xminlist = []
    ymaxlist = []
    yminlist = []
    for line in Lines:
        num = line.strip()[0]
        names.append(num)

    if '1' in names and '9' in names:

        for line in Lines:     
            if line.strip()[0] == '9':
                x4 = float(line.strip().split(' ')[1])
                y4 = float(line.strip().split(' ')[2])
                w4 = float(line.strip().split(' ')[3])
                h4 = float(line.strip().split(' ')[4])
                xmin = x4 - w4/2
                xmax = x4 + w4/2
                ymin = y4 - h4/2
                ymax = y4 + h4/2
                xmaxlist.append(xmin)
                xminlist.append(xmax)
                ymaxlist.append(ymin)
                yminlist.append(ymax)

        for line in Lines:   
            if line.strip()[0] == '1':
                x0 = float(line.strip().split(' ')[1])
                y0 = float(line.strip().split(' ')[2])
                for i in range(len(xmaxlist)):
                    print(i)
                    if xminlist[i] < x0 < xmaxlist[i]  and yminlist[i] < y0 < ymaxlist[i]:
                        files.append(line)

        print(files)
        # with open(i, 'w') as f:
        #     for line in Lines:
        #         if line not in files:
        #             f.write(line)

# %%
di_vat             0    
co_bac_truc        1
tray_bac_truc      2
day_vo_lon         3
dau_dinh_vi        4
co_lo_tap          5

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    files = []
    xmaxlist = []
    xminlist = []
    ymaxlist = []
    yminlist = []
    for line in Lines:
        num = line.strip()[0]
        names.append(num)

    if '1' in names and '2' in names:

        for line in Lines:     
            if line.strip()[0] == '2':
                x4 = float(line.strip().split(' ')[1])
                y4 = float(line.strip().split(' ')[2])
                w4 = float(line.strip().split(' ')[3])
                h4 = float(line.strip().split(' ')[4])
                xmin = x4 - w4/2
                xmax = x4 + w4/2
                ymin = y4 - h4/2
                ymax = y4 + h4/2
                xmaxlist.append(xmin)
                xminlist.append(xmax)
                ymaxlist.append(ymin)
                yminlist.append(ymax)

        for line in Lines:   
            if line.strip()[0] == '1':
                x0 = float(line.strip().split(' ')[1])
                y0 = float(line.strip().split(' ')[2])
                for i in range(len(xmaxlist)):
                    print(i)
                    if xminlist[i] < x0 < xmaxlist[i]  and yminlist[i] < y0 < ymaxlist[i]:
                        files.append(line)

# %%
di_vat 0 
co_bac_truc
tray_bac_truc
day_vo_lon 3
dau_dinh_vi 4

# %%
path = r'D:\NQVL_L82 - Copy\*.txt'

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    files = []
    for line in Lines:
        num = line.strip()[0]
        names.append(num)
    if '0' in names and '4' in names:
        for line in Lines:      
            if line.strip()[0] == '4':
                x4 = float(line.strip().split(' ')[1])
                y4 = float(line.strip().split(' ')[2])
                w4 = float(line.strip().split(' ')[3])
                h4 = float(line.strip().split(' ')[4])
                xmin = x4 - w4/2
                xmax = x4 + w4/2
                ymin = y4 - h4/2
                ymax = y4 + h4/2
        for line in Lines:   
            if line.strip()[0] == '0':
                x0 = float(line.strip().split(' ')[1])
                y0 = float(line.strip().split(' ')[2])
                if xmin < x0 < xmax  and ymin < y0 < ymax:
                    for line in Lines:  
                        if line.strip()[0] == '4':
                            files.append(line)
        with open(i, 'w') as f:
            for line in Lines:
                if line not in files:
                    f.write(line)
# Out:
# D:\NQVL_L82 - Copy\2122.txt
# D:\NQVL_L82 - Copy\2123.txt
# D:\NQVL_L82 - Copy\2124.txt
# D:\NQVL_L82 - Copy\2125.txt
# D:\NQVL_L82 - Copy\2126.txt
# D:\NQVL_L82 - Copy\2127.txt
# D:\NQVL_L82 - Copy\2128.txt
# D:\NQVL_L82 - Copy\2129.txt
# D:\NQVL_L82 - Copy\2130.txt
# D:\NQVL_L82 - Copy\2131.txt
# D:\NQVL_L82 - Copy\2132.txt
# D:\NQVL_L82 - Copy\2133.txt
# D:\NQVL_L82 - Copy\2134.txt
# D:\NQVL_L82 - Copy\2135.txt
# D:\NQVL_L82 - Copy\2136.txt
# D:\NQVL_L82 - Copy\2137.txt
# D:\NQVL_L82 - Copy\2138.txt
# D:\NQVL_L82 - Copy\2139.txt
# D:\NQVL_L82 - Copy\2140.txt
# D:\NQVL_L82 - Copy\2141.txt
# D:\NQVL_L82 - Copy\2142.txt
# D:\NQVL_L82 - Copy\2143.txt
# D:\NQVL_L82 - Copy\2144.txt
# D:\NQVL_L82 - Copy\2145.txt
# D:\NQVL_L82 - Copy\2146.txt
# D:\NQVL_L82 - Copy\2147.txt
# D:\NQVL_L82 - Copy\2148.txt
# D:\NQVL_L82 - Copy\2149.txt
# D:\NQVL_L82 - Copy\2150.txt
# D:\NQVL_L82 - Copy\2151.txt
# D:\NQVL_L82 - Copy\2152.txt
# D:\NQVL_L82 - Copy\2153.txt
# D:\NQVL_L82 - Copy\2154.txt
# ...

# %%
path = r'D:\cam1_image_all_test\*.txt'

# %%
bui_chi_han 
c 1
cham_keo
divat 3
khong_cham_keo
han_ok
han_thieu
me 7

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    files = []
    news = []
    for line in Lines:
        num = line.strip()[0]
        names.append(num)
    if '1' in names and '3' in names:
        for line in Lines:      
            if line.strip()[0] == '1':
                x4 = float(line.strip().split(' ')[1])
                y4 = float(line.strip().split(' ')[2])
                w4 = float(line.strip().split(' ')[3])
                h4 = float(line.strip().split(' ')[4])
                xmin = x4 - w4/2
                xmax = x4 + w4/2
                ymin = y4 - h4/2
                ymax = y4 + h4/2
        for line in Lines:   
            if line.strip()[0] == '3':
                x0 = float(line.strip().split(' ')[1])
                y0 = float(line.strip().split(' ')[2])
                if xmin < x0 < xmax  and ymin < y0 < ymax:
                    line = line.replace('3', '7')
            news.append(line)
                    #for line in Lines:  
                        #if line.strip()[0] == '3':
                        #    files.append(line)

        with open(i, 'w') as f:
            for line in news:
                f.write(line)
# Out:
# D:\cam1_image_all_test\0_jpg.rf.54f3bf3ea151c4e4af479d0982462412.txt
# D:\cam1_image_all_test\1000_jpg.rf.e2c486c39b6db1894f86e19752676978.txt
# D:\cam1_image_all_test\1001_jpg.rf.35528fb59474605e6cf5f8dcbb5e7d8e.txt
# D:\cam1_image_all_test\1002_jpg.rf.78b594702686969a3df2b578c2783c6a.txt
# D:\cam1_image_all_test\1003_jpg.rf.7dd69c282de57af7ebed3655ac1a79ba.txt
# D:\cam1_image_all_test\1004_jpg.rf.10342194116a0194e451845903ef5dbc.txt
# D:\cam1_image_all_test\1005_jpg.rf.814b7678ab0c7b9c036c02bee0882500.txt
# D:\cam1_image_all_test\1006_jpg.rf.447203417604fea1cffa1db53be3ad94.txt
# D:\cam1_image_all_test\1007_jpg.rf.2e4c35067b8a54d89da049cd7414bb59.txt
# D:\cam1_image_all_test\1008_jpg.rf.edf0b7ab8d12a6e8ab0208dfe80278b5.txt
# D:\cam1_image_all_test\1009_jpg.rf.5b08105b22601637a7ba0b65b5415b5e.txt
# D:\cam1_image_all_test\100_jpg.rf.8c198cf85a35e240e228e103bb991a1a.txt
# D:\cam1_image_all_test\1010_jpg.rf.54e8faf05232c4f9c1198f719c94b3b5.txt
# ...

# %%
path = r'C:\Users\Administrator\Pictures\MANH\All_C4_12_09_2022\*.txt'

# %%
import glob 
for i in glob.glob(path):
    print(i)
    file = open(i, 'r')
    Lines = file.readlines()
    names = []
    for line in Lines:
        w = line.strip().split(' ')[3]
        h = line.strip().split(' ')[4]
        
        if float(w)*416 > 3.1 and float(h)*416 > 3.1:
            names.append(line)
    with open(i,'w') as f:
        for name in names:
            f.write(name)

    #     names.append(num)
    # if '0' in names and '3' in names:
    #     print(names)
    #     with open(i,'w') as f:
    #         for line in Lines:
    #             if line.strip()[0] != "3":
    #                 f.write(line)
    # #                 f.write('\n')

# %%
0.01*416
# Out:
# 4.16

# %%
a = ['a',1],[1,2]

# %%
type(a)
# Out:
# tuple

# %%
a =list()

# %%
a = [[0]*10]*2

# %%
a = [[0] * 10 for i in range(2)]

# %%
len(a)
# Out:
# 2

# %%
a[0][1] = '2'

# %%
a = a.deepcopy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-6a186a7361c9> in <module>
# ----> 1 a = a.deepcopy()
#
# AttributeError: 'list' object has no attribute 'deepcopy'

# %%
a[0][0] = '1'

# %%
list_variable = [[0]*10]*4

# %%
list_variable[0][6] = 1

# %%
list_variable[0][6]
# Out:
# 1
